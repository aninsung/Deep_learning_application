# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/Users/user/Downloads/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# 데이터 확인
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (숫자)
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %%
Y = pd.get_dummies(y).values

# %%
X = X.values

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
Y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
X_train.shape[1]
# Out:
# 8

# %%
# 필요한 라이브러리 불러오기
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# PCA 객체 생성 (예: 4개의 주성분으로 차원 축소)
pca = PCA(n_components=4)
#pca = PCA(n_components=2)

# PCA 학습 및 변환
X_reduced = pca.fit_transform(X)

print("Explained variance ratio: ", pca.explained_variance_ratio_)

# 5. 결과 확인
print("원래 데이터의 차원: ", X.shape)  
print("차원 축소 후 데이터의 차원: ", X_reduced.shape) 

# 차원 축소된 데이터 시각화
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.title('PCA - 2D Projection')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# Explained variance ratio:  [0.88854663 0.06159078 0.02579012 0.01308614]
# 원래 데이터의 차원:  (768, 8)
# 차원 축소 후 데이터의 차원:  (768, 4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam
import tensorflow as tf

# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  dense (Dense)               (None, 14)                126
#
#  dense_1 (Dense)             (None, 7)                 105
#
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 8)                 64
#
# =================================================================
# Total params: 351
# Trainable params: 351
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 112ms/step - loss: 5572.4463 - val_loss: 5478.3765
# Epoch 2/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5557.0078 - val_loss: 5466.3398
# Epoch 3/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5546.0337 - val_loss: 5458.4961
# Epoch 4/50
# 3/3 [==============================] - 0s 17ms/step - loss: 5538.7129 - val_loss: 5453.2515
# Epoch 5/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5533.3662 - val_loss: 5449.5640
# Epoch 6/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5529.7222 - val_loss: 5446.8540
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5527.3271 - val_loss: 5444.1577
# Epoch 8/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5525.4648 - val_loss: 5442.0728
# Epoch 9/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5523.8086 - val_loss: 5440.7759
# Epoch 10/50
# 3/3 [==============================] - 0s 17ms/step - loss: 5522.8638 - val_loss: 5439.9761
# Epoch 11/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5522.3291 - val_loss: 5439.6914
# Epoch 12/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5522.0522 - val_loss: 5439.5957
# Epoch 13/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5521.8486 - val_loss: 5439.5552
# Epoch 14/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5521.6914 - val_loss: 5439.5044
# Epoch 15/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5521.5552 - val_loss: 5439.4473
# Epoch 16/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5521.4106 - val_loss: 5439.4004
# Epoch 17/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5521.2480 - val_loss: 5439.2373
# Epoch 18/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5521.0654 - val_loss: 5439.0479
# Epoch 19/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.9575 - val_loss: 5438.9585
# Epoch 20/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.9111 - val_loss: 5438.9209
# Epoch 21/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8921 - val_loss: 5438.9058
# Epoch 22/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8828 - val_loss: 5438.8970
# Epoch 23/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8784 - val_loss: 5438.8936
# Epoch 24/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8765 - val_loss: 5438.8911
# Epoch 25/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8740 - val_loss: 5438.8901
# Epoch 26/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8735 - val_loss: 5438.8887
# Epoch 27/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8726 - val_loss: 5438.8872
# Epoch 28/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8721 - val_loss: 5438.8872
# Epoch 29/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8716 - val_loss: 5438.8867
# Epoch 30/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8721 - val_loss: 5438.8867
# Epoch 31/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8716 - val_loss: 5438.8867
# Epoch 32/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8716 - val_loss: 5438.8857
# Epoch 33/50
# 3/3 [==============================] - 0s 24ms/step - loss: 5520.8716 - val_loss: 5438.8862
# Epoch 34/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8716 - val_loss: 5438.8853
# Epoch 35/50
# 3/3 [==============================] - 0s 26ms/step - loss: 5520.8711 - val_loss: 5438.8853
# Epoch 36/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8711 - val_loss: 5438.8862
# Epoch 37/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8721 - val_loss: 5438.8862
# Epoch 38/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8721 - val_loss: 5438.8862
# Epoch 39/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8721 - val_loss: 5438.8857
# Epoch 40/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8711 - val_loss: 5438.8848
# Epoch 41/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8711 - val_loss: 5438.8857
# Epoch 42/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8711 - val_loss: 5438.8857
# Epoch 43/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8711 - val_loss: 5438.8853
# Epoch 44/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8701 - val_loss: 5438.8848
# Epoch 45/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8706 - val_loss: 5438.8853
# Epoch 46/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8706 - val_loss: 5438.8848
# Epoch 47/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8706 - val_loss: 5438.8848
# Epoch 48/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8711 - val_loss: 5438.8843
# Epoch 49/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5520.8706 - val_loss: 5438.8843
# Epoch 50/50
# 3/3 [==============================] - 0s 21ms/step - loss: 5520.8706 - val_loss: 5438.8843

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');
