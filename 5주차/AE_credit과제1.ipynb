# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/Users/user/Downloads/diabetes.csv")
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# 데이터 확인
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (숫자)
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 6                               0.627   50
# 1                               0.351   31
# 8                               0.672   32
# 1                               0.167   21
# 0                               2.288   33

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %%
Y = pd.get_dummies(y).values

# %%
X = X.values

# %%
y
# Out:
# Pregnancies
# 6     1
# 1     0
# 8     1
# 1     0
# 0     1
#      ..
# 10    0
# 2     0
# 5     0
# 1     1
# 1     0
# Name: Outcome, Length: 768, dtype: int64

# %%
X
# Out:
# array([[148.   ,  72.   ,  35.   , ...,  33.6  ,   0.627,  50.   ],
#        [ 85.   ,  66.   ,  29.   , ...,  26.6  ,   0.351,  31.   ],
#        [183.   ,  64.   ,   0.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [121.   ,  72.   ,  23.   , ...,  26.2  ,   0.245,  30.   ],
#        [126.   ,  60.   ,   0.   , ...,  30.1  ,   0.349,  47.   ],
#        [ 93.   ,  70.   ,  31.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
Y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
X_train.shape[1]
# Out:
# 7

# %%
# 필요한 라이브러리 불러오기
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# PCA 객체 생성 (예: 4개의 주성분으로 차원 축소)
pca = PCA(n_components=4)
#pca = PCA(n_components=2)

# PCA 학습 및 변환
X_reduced = pca.fit_transform(X)

print("Explained variance ratio: ", pca.explained_variance_ratio_)

# 5. 결과 확인
print("원래 데이터의 차원: ", X.shape)  
print("차원 축소 후 데이터의 차원: ", X_reduced.shape) 

# 차원 축소된 데이터 시각화
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.title('PCA - 2D Projection')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# Explained variance ratio:  [0.88920966 0.06160576 0.02579683 0.01306647]
# 원래 데이터의 차원:  (768, 7)
# 차원 축소 후 데이터의 차원:  (768, 4)

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam
import tensorflow as tf

model = Sequential()

model.add(Dense(10,input_shape=(X_train.shape[1],),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(2,activation='sigmoid'))



model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                80
#
#  dense_5 (Dense)             (None, 8)                 88
#
#  dense_6 (Dense)             (None, 6)                 54
#
#  dense_7 (Dense)             (None, 2)                 14
#
# =================================================================
# Total params: 236
# Trainable params: 236
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 2s 24ms/step - loss: 0.7270 - accuracy: 0.4349 - val_loss: 0.7015 - val_accuracy: 0.4221
# Epoch 2/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6949 - accuracy: 0.6417 - val_loss: 0.6747 - val_accuracy: 0.7078
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6759 - accuracy: 0.6417 - val_loss: 0.6529 - val_accuracy: 0.7013
# Epoch 4/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6637 - accuracy: 0.6368 - val_loss: 0.6373 - val_accuracy: 0.6883
# Epoch 5/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.6417 - val_loss: 0.6271 - val_accuracy: 0.6948
# Epoch 6/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6513 - accuracy: 0.6401 - val_loss: 0.6205 - val_accuracy: 0.6948
# Epoch 7/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6485 - accuracy: 0.6401 - val_loss: 0.6155 - val_accuracy: 0.6948
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6459 - accuracy: 0.6401 - val_loss: 0.6113 - val_accuracy: 0.6948
# Epoch 9/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6441 - accuracy: 0.6401 - val_loss: 0.6065 - val_accuracy: 0.6948
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6427 - accuracy: 0.6401 - val_loss: 0.6037 - val_accuracy: 0.6948
# Epoch 11/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6416 - accuracy: 0.6401 - val_loss: 0.6026 - val_accuracy: 0.6948
# Epoch 12/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6400 - accuracy: 0.6401 - val_loss: 0.6000 - val_accuracy: 0.6948
# Epoch 13/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6394 - accuracy: 0.6401 - val_loss: 0.5992 - val_accuracy: 0.6948
# Epoch 14/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6382 - accuracy: 0.6401 - val_loss: 0.5963 - val_accuracy: 0.6948
# Epoch 15/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.6384 - val_loss: 0.5949 - val_accuracy: 0.6948
# Epoch 16/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6384 - val_loss: 0.5927 - val_accuracy: 0.6948
# Epoch 17/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6336 - accuracy: 0.6384 - val_loss: 0.5902 - val_accuracy: 0.6948
# Epoch 18/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.6384 - val_loss: 0.5884 - val_accuracy: 0.6948
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6316 - accuracy: 0.6384 - val_loss: 0.5867 - val_accuracy: 0.6948
# Epoch 20/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6296 - accuracy: 0.6384 - val_loss: 0.5840 - val_accuracy: 0.6948
# Epoch 21/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6283 - accuracy: 0.6384 - val_loss: 0.5827 - val_accuracy: 0.6948
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6268 - accuracy: 0.6401 - val_loss: 0.5836 - val_accuracy: 0.6883
# Epoch 23/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6267 - accuracy: 0.6384 - val_loss: 0.5808 - val_accuracy: 0.6948
# Epoch 24/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6268 - accuracy: 0.6384 - val_loss: 0.5755 - val_accuracy: 0.6883
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6223 - accuracy: 0.6384 - val_loss: 0.5731 - val_accuracy: 0.6883
# Epoch 26/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6221 - accuracy: 0.6384 - val_loss: 0.5744 - val_accuracy: 0.6883
# Epoch 27/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6212 - accuracy: 0.6368 - val_loss: 0.5722 - val_accuracy: 0.6948
# Epoch 28/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6183 - accuracy: 0.6368 - val_loss: 0.5730 - val_accuracy: 0.6883
# Epoch 29/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6175 - accuracy: 0.6287 - val_loss: 0.5668 - val_accuracy: 0.6948
# Epoch 30/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6164 - accuracy: 0.6352 - val_loss: 0.5692 - val_accuracy: 0.6948
# 5/5 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.99      0.82       107
#            1       0.50      0.02      0.04        47
#
#     accuracy                           0.69       154
#    macro avg       0.60      0.51      0.43       154
# weighted avg       0.64      0.69      0.58       154
#
# [[106   1]
#  [ 46   1]]
